# %% [markdown]
# This notebook enables to run the streamlit app via Colab.

# %% [markdown]
# # 0 Colab Setup

# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

#change path_to_data to your project folder
path_to_data = ['drive','My Drive', 'bi-pyt', 'semestral_project']
root_path = os.path.join(*path_to_data)

os.chdir(root_path)
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/My Drive/bi-pyt/semestral_project'

# %%
# install missing dependencies
# !pip install streamlit
# !pip install pyngrok
# !pip install tensorflow_addons

# %% [markdown]
# # 1 Run Streamlit App

# %%
from pyngrok import ngrok 
# !ngrok authtoken 1rIw1KWoUSKQ40zwuVs1ZSqOHMc_6EdmezpLqReBs1QdBiQ7K
# !nohup streamlit run streamlit_app_local.py & 

# click on the generated URL to open the app
url = ngrok.connect(port = 8501)
print(url)

# !streamlit run --server.port 80 streamlit_app_local.py >/dev/null
